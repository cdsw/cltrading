# %%
import pandas as pd
hourly_bear_data = pd.read_pickle('hourly_bear.pkl')
minute_bull_data = pd.read_pickle('minutely_bull.pkl')
hourly_bull_data = pd.read_pickle('hourly_bull.pkl')
minute_crab_data = pd.read_pickle('minutely_crab.pkl')
trainh_data = pd.read_pickle('trunc_data.pkl')

# %%
minute_bull_data
# Out:
#                          high       low      open     close           ewm  \
# time
# 2023-02-14 04:40:00  21744.54  21740.71  21744.42  21740.88  21740.880000
# 2023-02-14 04:41:00  21744.88  21740.58  21740.88  21744.09  21741.101379
# 2023-02-14 04:42:00  21744.64  21743.74  21744.09  21744.55  21741.339215
# 2023-02-14 04:43:00  21744.55  21740.33  21744.55  21740.52  21741.282718
# 2023-02-14 04:44:00  21740.52  21733.91  21740.52  21734.18  21740.792875
# ...                       ...       ...       ...       ...           ...
# 2023-02-15 13:56:00  22734.46  22722.95  22732.99  22723.87  22734.866055
# 2023-02-15 13:57:00  22723.87  22712.32  22723.87  22712.90  22733.351155
# 2023-02-15 13:58:00  22713.26  22703.47  22712.90  22704.37  22731.352455
# 2023-02-15 13:59:00  22704.37  22698.08  22704.37  22700.95  22729.255734
# 2023-02-15 14:00:00  22702.74  22697.34  22700.95  22699.29  22727.189131
#
#                      macd_histo    return
# time
# ...

# %%
# # hourly_bear_data
# import matplotlib.pyplot as plt
# import numpy as np

# dat = minute_crab_data
# xpoints = dat.index
# ypoints = dat['close']
# ypoints_ret = dat['return']

# plt.rcParams["figure.figsize"] = (15,4)
# fig, ax1 = plt.subplots()
# ax2 = ax1.twinx()

# ax1.plot(xpoints, ypoints, 'k-', linewidth=0.7)
# ax2.plot(xpoints, ypoints_ret, 'r-', linewidth=0.2)

# ax1.set_ylabel('BTC Price', color='k')
# ax2.set_ylabel('Return', color='r')

# # plt.plot(xpoints[14:], ypoints_ma)
# plt.show()

# %%
# import torch
# torch.cuda.is_available()
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Number of trades
import pandas as pd
dat_ppo_disc = pd.read_pickle('resultsnew/results/ppo-disc-results.pkl')
dat_ppo_cont = pd.read_pickle('resultsnew/results/ppo-cont-results.pkl')
dat_a2c_disc = pd.read_pickle('resultsnew/results/a2c-disc-results.pkl')
dat_a2c_cont = pd.read_pickle('resultsnew/results/a2c-cont-results.pkl')
dat_dqn = pd.read_pickle('resultsnew/results/dqn-disc-results.pkl')
dat_sac = pd.read_pickle('resultsnew/results/sac-cont-results.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-c140d27380f8> in <module>
#       1 # Number of trades
#       2 import pandas as pd
# ----> 3 dat_ppo_disc = pd.read_pickle('resultsnew/results/ppo-disc-results.pkl')
#       4 dat_ppo_cont = pd.read_pickle('resultsnew/results/ppo-cont-results.pkl')
#       5 dat_a2c_disc = pd.read_pickle('resultsnew/results/a2c-disc-results.pkl')
#
# c:\users\clementich\appdata\local\programs\python\python37\lib\site-packages\pandas\io\pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     220                 #  "No module named 'pandas.core.sparse.series'"
#     221                 #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
# --> 222                 return pc.load(handles.handle, encoding=None)
#     223         except UnicodeDecodeError:
# ...
